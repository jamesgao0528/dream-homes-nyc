# %%
import psycopg2

conn = psycopg2.connect(
    host="database-2.ct6ykb0jdh0t.us-east-1.rds.amazonaws.com",
    port=5432,
    database="postgres",
    user="postgres",
    password="postgres"
)

cur = conn.cursor()
cur.execute("SELECT version();")
print(cur.fetchone())

cur.close()
conn.close()
# Out:
# ('PostgreSQL 17.6 on x86_64-pc-linux-gnu, compiled by gcc (GCC) 12.4.0, 64-bit',)
