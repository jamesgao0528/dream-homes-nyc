# %%
# !pip install psycopg2-binary
# Out:
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
from sqlalchemy import create_engine, text
import pandas as pd

DATABASE_URL = "postgresql://postgres:postgres@localhost:5433/dreamhomes"
engine = create_engine(DATABASE_URL)
print("Connected successfully")
# Out:
# Connected successfully

# %%
def run_sql(sql):
    with engine.connect() as conn:
        conn.execute(text(sql))
        conn.commit()
    print("Done.")

# %%
run_sql("""
DROP TABLE IF EXISTS commission CASCADE;
DROP TABLE IF EXISTS sale_transaction CASCADE;
DROP TABLE IF EXISTS lease_transaction CASCADE;
DROP TABLE IF EXISTS property_transaction CASCADE;
DROP TABLE IF EXISTS client_listing_interaction CASCADE;
DROP TABLE IF EXISTS appointment CASCADE;
DROP TABLE IF EXISTS open_house CASCADE;
DROP TABLE IF EXISTS client_preference CASCADE;
DROP TABLE IF EXISTS client CASCADE;
DROP TABLE IF EXISTS zip_market_trend CASCADE;
DROP TABLE IF EXISTS listing_price_history CASCADE;
DROP TABLE IF EXISTS listing CASCADE;
DROP TABLE IF EXISTS property_amenity CASCADE;
DROP TABLE IF EXISTS property CASCADE;
DROP TABLE IF EXISTS neighborhood CASCADE;
DROP TABLE IF EXISTS school_district CASCADE;
DROP TABLE IF EXISTS office_financials CASCADE;
DROP TABLE IF EXISTS agent CASCADE;
DROP TABLE IF EXISTS employee CASCADE;
DROP TABLE IF EXISTS office CASCADE;
DROP TABLE IF EXISTS amenity CASCADE;
DROP TABLE IF EXISTS state CASCADE;
""")
# Out:
# Done.

# %%
with open("dream_homes_schema_final.sql", "r") as f:
    schema_sql = f.read()

# Split on semicolons, strip whitespace, skip empty and comment-only blocks
statements = []
for s in schema_sql.split(";"):
    stripped = s.strip()
    # Remove comment lines and check if anything real remains
    non_comment_lines = [
        line for line in stripped.splitlines()
        if line.strip() and not line.strip().startswith("--")
    ]
    if non_comment_lines:
        statements.append(stripped)

with engine.connect() as conn:
    for statement in statements:
        conn.execute(text(statement))
    conn.commit()

print(f"Executed {len(statements)} statements successfully.")
# Out:
# Executed 40 statements successfully.
