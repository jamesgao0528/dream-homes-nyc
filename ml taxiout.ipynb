# %%
import pandas as pd

DATA_PATH = r'C:\Users\User\Downloads\Cleaned_US_Flights_Infrastructure.csv'

# 只读第一行来获取列名，不加载整个742MB文件
df_preview = pd.read_csv(DATA_PATH, nrows=5)

print("=== 所有列名 ===")
for i, col in enumerate(df_preview.columns):
    print(f"{i:3d}. {col}")

print(f"\n总列数: {len(df_preview.columns)}")
print(f"\n=== 前5行预览 ===")
print(df_preview.head())
# Out:
# === 所有列名 ===
#   0. MONTH
#   1. FL_DATE
#   2. OP_UNIQUE_CARRIER
#   3. OP_CARRIER_AIRLINE_ID
#   4. OP_CARRIER_FL_NUM
#   5. ORIGIN_AIRPORT_ID
#   6. ORIGIN_AIRPORT_SEQ_ID
#   7. ORIGIN_CITY_MARKET_ID
#   8. ORIGIN
#   9. ORIGIN_CITY_NAME
#  10. ORIGIN_STATE_ABR
#  11. DEST_AIRPORT_ID
#  12. DEST_AIRPORT_SEQ_ID
#  13. DEST_CITY_MARKET_ID
#  14. DEST
#  15. DEST_CITY_NAME
#  16. DEST_STATE_ABR
#  17. DEP_DELAY
#  18. DEP_DELAY_NEW
#  19. DEP_DEL15
#  20. DEP_DELAY_GROUP
#  21. DEP_TIME_BLK
#  22. TAXI_OUT
#  23. TAXI_IN
#  24. ARR_DELAY
#  25. ARR_DELAY_NEW
#  26. ARR_DEL15
#  27. ARR_DELAY_GROUP
#  28. ARR_TIME_BLK
#  29. CANCELLED
#  30. CANCELLATION_CODE
#  31. CARRIER_DELAY
#  32. WEATHER_DELAY
#  33. NAS_DELAY
#  34. SECURITY_DELAY
#  35. LATE_AIRCRAFT_DELAY
#  36. CRS_DEP_DATETIME
#  37. ACT_DEP_DATETIME
#  38. CRS_ARR_DATETIME
#  39. ACT_ARR_DATETIME
#  40. ORG_PASSENGERS
#  41. DEST_PASSENGERS
#  42. ORG_NUM_RUNWAYS
#  43. ORG_MAX_RUNWAY_LENGTH
#  44. ORG_TOTAL_RUNWAY_AREA
# ...
